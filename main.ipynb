# %%
# %matplotlib inline
# %run main.py
# Out:
# 2026-06-26 15:22:27,227 [INFO] (main.py:430) - === Starting Optical Network RMSA Validation Framework ===
# 2026-06-26 15:22:27,229 [INFO] (main.py:436) - Processing network topology: G17
# 2026-06-26 15:22:27,241 [INFO] (main.py:43) - Topology successfully built from G17-topology.txt. Nodes: 17, Edges: 52
# ...
# Net   | Mat   | Algorithm                  | Alloc/Blk | BP(%)  | HighFSU | TotalFSU | AvgHop  | Cost    | RSS    | NoC    | Time(s)
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# G17   | M1    | Benchmark                  | 241/0         | 0.00   | 182     | 1749     | 2.8     | 813.9   | 5289.4 | 225   | 0.2389
# G17   | M1    | Benchmark                  | 241/0         | 0.00   | 185     | 1749     | 2.8     | 813.9   | 5345.5 | 214   | 0.2034
# ...
