# %%
# %matplotlib inline
# %run main.py
# Out:
# ...
# Net   | Mat   | Algorithm                  | Alloc/Blk | BP(%)  | HighFSU | TotalFSU | AvgHop  | Cost    | RSS    | NoC
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# G17   | M1    | Benchmark                  | 241/0         | 0.00   | 182     | 1749     | 2.8     | 813.9   | 5289.4 | 225
# G17   | M1    | Benchmark                  | 241/0         | 0.00   | 185     | 1749     | 2.8     | 813.9   | 5345.5 | 214
# G17   | M1    | Custom(NoC-aware Best-Fit) | 241/0         | 0.00   | 319     | 1519     | 2.7     | 759.6   | 5984.5 | 193
# G17   | M1    | Custom(NoC-aware Best-Fit) | 241/0         | 0.00   | 319     | 1564     | 2.7     | 772.0   | 5962.8 | 172
# G17   | M1    | 1+1 Protection (First-Fit) | 241/0         | 0.00   | 284     | 3727     | 3.5     | 1430.8  | 2388.4 | 546
# ...
